# %% [markdown]
# **Gathering**

# %%
import pandas as pd
import numpy as np
import os
import requests
import re
import tweepy
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
archive_df = pd.read_csv('twitter-archive-enhanced.csv')
archive_df.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
url = ' https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
r_Image = requests.get(url)
r_Image
# Out:
# <Response [200]>

# %%
#create folder for image predication data 
file_name=url.split('/')[-1]

# %%
if not os.path.isfile(file_name):
    with open(file_name, 'wb') as f:
        f.write(r_Image.content)

# %%
image_predication_df = pd.read_csv('image-predictions.tsv',sep='\t')

# %%
image_predication_df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
# Exploration of data types and missing fields.
image_predication_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# **Twitter API**

# %%
# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_1.tweet_id.values
len(tweet_ids)

# %%
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %%
df_list = []
tweet_json = open('tweet-json.txt','r')
for line in tweet_json:
    df_list.append( json.loads(line))

tweet_json.close()

# %%
df_list[0]
# Out:
# {'created_at': 'Tue Aug 01 16:23:56 +0000 2017',
#  'id': 892420643555336193,
#  'id_str': '892420643555336193',
#  'full_text': "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU",
#  'truncated': False,
#  'display_text_range': [0, 85],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [],
#   'media': [{'id': 892420639486877696,
#     'id_str': '892420639486877696',
#     'indices': [86, 109],
#     'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'url': 'https://t.co/MgUWQ76dJU',
#     'display_url': 'pic.twitter.com/MgUWQ76dJU',
#     'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 540, 'h': 528, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
# ...

# %%
api_df = pd.DataFrame()
api_df['id'] = list(map(lambda tweet:tweet['id'],df_list))
api_df['retweet_count'] = list(map(lambda tweet: tweet['retweet_count'],df_list ))

api_df['favorite_count'] = list(map(lambda tweet: tweet['favorite_count'], df_list))

# %%
api_df
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %% [markdown]
# # Assess

# %%
api_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# id                2354 non-null int64
# retweet_count     2354 non-null int64
# favorite_count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
api_df.describe()
#  id can be string not int ---> Quality issue
# Out:
#                  id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
archive_df.name.value_counts()
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Lucy        11
#           ...
# Perry        1
# Willem       1
# Alfy         1
# Jaspers      1
# Jett         1
# Name: name, Length: 957, dtype: int64

# %%
archive_df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
archive_df.rating_denominator.value_counts()
#deminator must be fixed 10
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
archive_df.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
archive_df.doggo.value_counts()
#tidness can be one column with the value
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %% [markdown]
# #Quality issues
# 1)completeness
# we will remove the rows without image in image predication

# %%
# coping all dfs 
archive_clean = archive_df.copy()
image_predicat_clean = image_predication_df.copy()
api_clean = api_df.copy()

# %%
#Creating a list of tweet_ids with image 
tweets_with_image = list(image_predicat_clean.tweet_id.unique())

#confirming that all tweets with images exist in archive dataset
len(tweets_with_image) == archive_clean.tweet_id.isin(tweets_with_image).sum()

#cleaning in action 
archive_clean = archive_clean[archive_clean.tweet_id.isin(tweets_with_image)]

# %%
#test
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2075 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2075 non-null object
# source                        2075 non-null object
# text                          2075 non-null object
# retweeted_status_id           81 non-null float64
# retweeted_status_user_id      81 non-null float64
# retweeted_status_timestamp    81 non-null object
# expanded_urls                 2075 non-null object
# rating_numerator              2075 non-null int64
# rating_denominator            2075 non-null int64
# name                          2075 non-null object
# doggo                         2075 non-null object
# floofer                       2075 non-null object
# pupper                        2075 non-null object
# ...

# %%
# Throwback to the archive dataset to extract the tweets that include data in the retweet_status_id.

retweet_entries = archive_clean.retweeted_status_id.notnull()
archive_clean[retweet_entries].shape[0]

# Dropping the retweets from the archive data set
archive_clean = archive_clean[~retweet_entries]

# Now we check the image_prediction table for extra tweet ids not in the archive table
np.logical_not(image_predicat_clean.tweet_id.isin(list(archive_clean.tweet_id)))

# Dropping the retweets and replies ids from the image prediction dataframe
image_predicat_clean[~np.logical_not(image_predicat_clean.tweet_id.isin(list(archive_clean.tweet_id)))]
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
api_clean[~np.logical_not(api_clean.id.isin(list(archive_clean.tweet_id)))]
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [1994 rows x 3 columns]

# %%
# Rename column in Api_tweet to be same name in the other two dataframe Quality Issue
api_clean.rename(columns={'id':'tweet_id'},inplace=True)
api_clean.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %% [markdown]
# ##`Tidness issues`
# **
# 1) Create a new column stage for the four stages of dog and drop the four columns of stages
# 2)Merge Tweet_archive and tweet_api
# **

# %%
# 1)Create a new column stage for the four stages of dog and drop the four columns of stage

stage = ['doggo','pupper','floofer','puppo']
for i in stage:
    archive_clean[i] = archive_clean[i].replace('None','')

# %%
archive_clean['stage'] = archive_clean['doggo'] + archive_clean['pupper'] + archive_clean['floofer'] + archive_clean['puppo']
 
#drop the four column 
archive_clean = archive_clean.drop(['doggo','pupper','floofer','puppo'],axis=1)

archive_clean.stage.value_counts()
# Out:
#                 1688
# pupper           203
# doggo             63
# puppo             22
# doggopupper        9
# floofer            7
# doggopuppo         1
# doggofloofer       1
# Name: stage, dtype: int64

# %%
archive_clean.loc[archive_clean.stage == 'doggopupper','stage'] = 'doggo-pupper'
archive_clean.loc[archive_clean.stage == 'doggopuppo','stage'] = 'doggo-puppo'
archive_clean.loc[archive_clean.stage == 'doggofloofer','stage'] = 'doggo-floofer'
archive_clean['stage']= archive_clean['stage'].replace(' ',np.nan)
archive_clean.stage.value_counts()
# Out:
#                  1688
# pupper            203
# doggo              63
# puppo              22
# doggo-pupper        9
# floofer             7
# doggo-floofer       1
# doggo-puppo         1
# Name: stage, dtype: int64

# %%
archive_clean.tail(20)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2336  666273097616637952                    NaN                  NaN
# 2337  666268910803644416                    NaN                  NaN
# 2338  666104133288665088                    NaN                  NaN
# 2339  666102155909144576                    NaN                  NaN
# 2340  666099513787052032                    NaN                  NaN
# 2341  666094000022159362                    NaN                  NaN
# 2342  666082916733198337                    NaN                  NaN
# 2343  666073100786774016                    NaN                  NaN
# 2344  666071193221509120                    NaN                  NaN
# 2345  666063827256086533                    NaN                  NaN
# 2346  666058600524156928                    NaN                  NaN
# 2347  666057090499244032                    NaN                  NaN
# 2348  666055525042405380                    NaN                  NaN
# ...

# %%
#  second -->Merging  the two dataframe with inner join as we have a join key  tidness issue
archive_clean = pd.merge(archive_clean,api_clean,on='tweet_id',how='inner')

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
# tweet_id                      1994 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     1994 non-null object
# source                        1994 non-null object
# text                          1994 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1994 non-null object
# rating_numerator              1994 non-null int64
# rating_denominator            1994 non-null int64
# name                          1994 non-null object
# stage                         1994 non-null object
# retweet_count                 1994 non-null int64
# favorite_count                1994 non-null int64
# dtypes: float64(4), int64(5), object(7)
# ...

# %% [markdown]
# `Quality ISSUES`
# In Archive_clean df
# 1- completeness we will remove the rows without image in image predication  (Done above )
# 2- Remove retweets (non originonal tweet) (Done) (complettnes issue )
# 3-  datatype of timestamp isn't correct
# 4- the standard of rating denminator is 10 but it include some other numbers
# 5- the rating numerator has  also some incorrect values
# 6- Many incorrect names is found like a , an
# 7- the dog name sometimes start with capital and sometimes small make it same formate
# ###########################################################
# IN Image_predication_df
# 8-some columns name have are not clear like p1 , p2

# %% [markdown]
# Code  datatype of timestamp isn't correct

# %%
archive_clean.timestamp = pd.to_datetime(archive_clean.timestamp)

# %%
#Test 
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 16 columns):
# tweet_id                      1994 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     1994 non-null datetime64[ns, UTC]
# source                        1994 non-null object
# text                          1994 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1994 non-null object
# rating_numerator              1994 non-null int64
# rating_denominator            1994 non-null int64
# name                          1994 non-null object
# stage                         1994 non-null object
# retweet_count                 1994 non-null int64
# favorite_count                1994 non-null int64
# ...

# %% [markdown]
# `Code` 3- the standard of rating denminator is 10 but it include some other numbers

# %%
#trying toknow where is the fault
df_denminator = archive_clean[archive_clean['rating_denominator'] != 10]
df_denminator[['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id                                               text  \
# 323   820690176645140481  The floofs have been released I repeat the flo...
# 385   810984652412424192  Meet Sam. She smiles 24/7 &amp; secretly aspir...
# 662   758467244762497024  Why does this never happen at my front door......
# 800   740373189193256964  After so many requests, this is Bretagne. She ...
# 848   731156023742988288  Say hello to this unbelievably well behaved sq...
# 891   722974582966214656  Happy 4/20 from the squad! 13/10 for all https...
# 925   716439118184652801  This is Bluebert. He just saw that both #Final...
# 946   713900603437621249  Happy Saturday here's 9 puppers on a bench. 99...
# 970   710658690886586372  Here's a brigade of puppers. All look very pre...
# 988   709198395643068416  From left to right:\nCletus, Jerome, Alejandro...
# 1054  704054845121142784  Here is a whole flock of puppers.  60/50 I'll ...
# ...

# %%
# the diff in text from the deninator 
#740373189193256964,722974582966214656,716439118184652801,682962037429899265,666287406224695296

archive_clean.loc[archive_clean.tweet_id == 740373189193256964, ['rating_denominator']] = 10
archive_clean.loc[archive_clean.tweet_id == 722974582966214656, ['rating_denominator']] = 10
archive_clean.loc[archive_clean.tweet_id == 716439118184652801, ['rating_denominator']] = 10
archive_clean.loc[archive_clean.tweet_id == 682962037429899265, ['rating_denominator']] = 10
archive_clean.loc[archive_clean.tweet_id == 666287406224695296, ['rating_denominator']] = 10

# %%
# Test
archive_clean.loc[archive_clean.tweet_id == 716439118184652801]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 925  716439118184652801                    NaN                  NaN
#
#                     timestamp  \
# 925 2016-04-03 01:36:11+00:00
#
#                                                 source  \
# 925  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 925  This is Bluebert. He just saw that both #Final...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 925                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 925  https://twitter.com/dog_rates/status/716439118...                50
#
#      rating_denominator      name stage  retweet_count  favorite_count
# 925                  10  Bluebert                  247            2574

# %% [markdown]
# `Code` 4- the rating numerator has  also some incorrect values

# %%
archive_clean.loc[archive_clean.tweet_id == 740373189193256964, ['rating_numerator']] = 14
archive_clean.loc[archive_clean.tweet_id == 722974582966214656, ['rating_numerator']] = 13
archive_clean.loc[archive_clean.tweet_id == 716439118184652801, ['rating_numerator']] = 11
archive_clean.loc[archive_clean.tweet_id == 682962037429899265, ['rating_numerator']] = 10
archive_clean.loc[archive_clean.tweet_id == 666287406224695296, ['rating_numerator']] = 9

# %%
#Test 
archive_clean.loc[archive_clean.tweet_id == 716439118184652801]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 925  716439118184652801                    NaN                  NaN
#
#                     timestamp  \
# 925 2016-04-03 01:36:11+00:00
#
#                                                 source  \
# 925  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 925  This is Bluebert. He just saw that both #Final...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 925                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 925  https://twitter.com/dog_rates/status/716439118...                11
#
#      rating_denominator      name stage  retweet_count  favorite_count
# 925                  10  Bluebert                  247            2574

# %% [markdown]
# `code` 5-Change the frequent incorrect dog name

# %%
archive_clean['name'].value_counts().head(15)
# Out:
# None       546
# a           55
# Charlie     11
# Cooper      10
# Oliver      10
# Lucy        10
# Penny        9
# Tucker       9
# Winston      8
# Sadie        8
# Lola         7
# the          7
# Toby         7
# Daisy        7
# Stanley      6
# Name: name, dtype: int64

# %% [markdown]
# 6)
# #after more than one assess i find that the most frequent in correct
# #not_correct = ['a','an','the']
# #for i in not_correct:
#     #archive_clean['name'].replace(i,'None',inplace=True)

# %%
pattern_2 = re.compile(r'(?:name(?:d)?)\s{1}(?:is\s)?([A-Za-z]+)')
for index, row in archive_clean.iterrows():  
    try:
        if row['name'] == "a":
            c_name = re.findall(pattern_2, row['text'])[0]
            archive_clean.loc[index,'name'] = archive_clean.loc[index,'name'].replace('a', c_name)
        elif row['name'] == 'an':
            c_name = re.findall(pattern_2, row['text'])[0]
            archive_clean.loc[index,'name'] = archive_clean.loc[index,'name'].replace('an', c_name)
    except IndexError:
        archive_clean.loc[index,'name'] = np.nan

            
archive_clean.name.value_counts(dropna = False)
# Out:
# None       546
# NaN         40
# Charlie     11
# Lucy        10
# Oliver      10
#           ...
# not          1
# Kellogg      1
# Tonks        1
# Mo           1
# Snoopy       1
# Name: name, Length: 953, dtype: int64

# %%
#Test
archive_clean['name'].value_counts().head(15)
# Out:
# None       546
# Charlie     11
# Lucy        10
# Cooper      10
# Oliver      10
# Penny        9
# Tucker       9
# Winston      8
# Sadie        8
# Toby         7
# Daisy        7
# Lola         7
# the          7
# Bo           6
# Koda         6
# Name: name, dtype: int64

# %% [markdown]
#  `code `7-the dog name sometimes start with capital and sometimes small make it same formate

# %%
archive_clean['name'].str.islower().sum()
# Out:
# 37

# %%
# So the the number of names start with lower is small so we will captiliza all 
archive_clean ['name'] = archive_clean.name.str.capitalize()

# %%
# Test again and should be Zero 
archive_clean['name'].str.islower().sum()
# Out:
# 0

# %% [markdown]
# 8-optimize source column

# %%
archive_clean['source'].value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     1955
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       28
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
archive_clean['source'] = archive_clean['source'].replace('<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
                                                                          'Twitter for iphone')
archive_clean['source'] =  archive_clean['source'].replace('<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
                                                                           'Twitter Web Client')
archive_clean['source'] =  archive_clean['source'].replace('<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
                                                                           'TweetDeck')

# %% [markdown]
# IN Image_predication_df
# 9-some columns name have are not clear like p1 , p2

# %%
image_predicat_clean.rename(columns={'p1':'first_prediction', 'p1_conf': 'first_confidence', 'p1_dog': 'first_dog',
                                  'p2': 'second_prediction', 'p2_conf': 'second_confidence', 'p2_dog': 'second_dog',
                                  'p3': 'third_prediction', 'p3_conf': 'third_confidence', 'p3_dog': 'third_dog'}, inplace = True)

# %%
#test
image_predicat_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num        first_prediction  first_confidence  first_dog  \
# 0        1  Welsh_springer_spaniel          0.465074       True
# 1        1                 redbone          0.506826       True
# 2        1         German_shepherd          0.596461       True
# 3        1     Rhodesian_ridgeback          0.408143       True
# 4        1      miniature_pinscher          0.560311       True
#
#     second_prediction  second_confidence  second_dog     third_prediction  \
# 0              collie           0.156665        True    Shetland_sheepdog
# ...

# %%
twitter_archive_master = pd.merge(archive_clean , image_predicat_clean ,on="tweet_id",how="inner")
twitter_archive_master.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp              source  \
# 0 2017-08-01 16:23:56+00:00  Twitter for iphone
# 1 2017-08-01 00:17:27+00:00  Twitter for iphone
# 2 2017-07-31 00:18:03+00:00  Twitter for iphone
# 3 2017-07-30 15:58:51+00:00  Twitter for iphone
# 4 2017-07-29 16:00:24+00:00  Twitter for iphone
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# ...

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 27 columns):
# tweet_id                      1994 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     1994 non-null datetime64[ns, UTC]
# source                        1994 non-null object
# text                          1994 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1994 non-null object
# rating_numerator              1994 non-null int64
# rating_denominator            1994 non-null int64
# name                          1954 non-null object
# stage                         1994 non-null object
# retweet_count                 1994 non-null int64
# favorite_count                1994 non-null int64
# ...

# %% [markdown]
# 9-All tweets id are integer
# (rather than change it in each df before Merging them together )

# %%
twitter_archive_master["tweet_id"] = twitter_archive_master["tweet_id"].astype(str)

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 27 columns):
# tweet_id                      1994 non-null object
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     1994 non-null datetime64[ns, UTC]
# source                        1994 non-null object
# text                          1994 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1994 non-null object
# rating_numerator              1994 non-null int64
# rating_denominator            1994 non-null int64
# name                          1954 non-null object
# stage                         1994 non-null object
# retweet_count                 1994 non-null int64
# favorite_count                1994 non-null int64
# ...

# %%
twitter_archive_master.to_csv('twitter_archive_master.csv',encoding='utf-8')

# %% [markdown]
# # Analyze and visualize

# %% [markdown]
# # 1- Retweet_count and favorite_count

# %%
twitter_archive_master.corr(method='pearson').head(10)
# Out:
#                           in_reply_to_status_id  in_reply_to_user_id  \
# in_reply_to_status_id                  1.000000                  NaN
# in_reply_to_user_id                         NaN                  NaN
# retweeted_status_id                         NaN                  NaN
# retweeted_status_user_id                    NaN                  NaN
# rating_numerator                      -0.078811                  NaN
# rating_denominator                    -0.067949                  NaN
# retweet_count                          0.167515                  NaN
# favorite_count                         0.595754                  NaN
# img_num                                0.076881                  NaN
# first_confidence                       0.425057                  NaN
#
#                           retweeted_status_id  retweeted_status_user_id  \
# in_reply_to_status_id                     NaN                       NaN
# ...

# %%
 # Preason number is 0.912947 a strong relation between retweet_count and favorite_count 
    
sns.regplot(x="retweet_count", y="favorite_count", data=twitter_archive_master)
plt.title('Retweet_count and favorite_count Correlation')
# Out:
# Text(0.5, 1.0, 'Retweet_count and favorite_count Correlation')

# %% [markdown]
# # The Classification of Dogs Results Analysis

# %%
twitter_archive_master['first_prediction'].value_counts().head(10)
# Out:
# golden_retriever      139
# Labrador_retriever     95
# Pembroke               88
# Chihuahua              79
# pug                    54
# chow                   41
# Samoyed                40
# Pomeranian             38
# toy_poodle             38
# malamute               29
# Name: first_prediction, dtype: int64

# %%
sns.set(style='darkgrid')
ax = sns.distplot(twitter_archive_master['first_confidence'])

# %% [markdown]
# # The distrbution of the source

# %%
sorted_source = twitter_archive_master['source'].value_counts().index
print(twitter_archive_master['source'].value_counts())
sns.set(style="darkgrid")
sns.countplot(data = twitter_archive_master, y = 'source', order = sorted_source)
plt.xticks(rotation = 360)
plt.xlabel('Count', fontsize=14)
plt.ylabel('Source', fontsize=14)
plt.title('The Distribution of Source',fontsize=16)
# Out:
# Twitter for iphone    1955
# Twitter Web Client      28
# TweetDeck               11
# Name: source, dtype: int64
# Text(0.5, 1.0, 'The Distribution of Source')

# %%
sns.set_context(context='notebook')
sns.set(rc={'figure.figsize':(10,6)})
avg_retweet_count_dog_stage = twitter_archive_master.groupby('stage').retweet_count.mean()

# the index with stand for the x axis in plotting 
avg_retweet_count_dog_stage.index

avg_favorite_count_dog_stage = twitter_archive_master.groupby('stage').favorite_count.mean()  

colors = ['red','white']
width = 0.5


plt.xlabel('stage',fontsize=15)
plt.ylabel('count_mean',fontsize=15)
plt.title('Dog_stages vs Count_mean ')
red_bars = plt.bar(avg_retweet_count_dog_stage.index, avg_retweet_count_dog_stage, width, color='r', alpha=.7, label='avg_retweet')
white_bars = plt.bar(width+np.arange(len(avg_retweet_count_dog_stage.index)),avg_favorite_count_dog_stage, width, color='w', alpha=.7, label='avg_favorite')
plt.legend()
